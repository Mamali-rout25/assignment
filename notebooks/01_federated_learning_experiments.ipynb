# %% [markdown]
# # Federated Learning Experiments Notebook
#
# This notebook demonstrates how to run the full experiment suite for the healthcare federated learning assignment. It loads the prepared datasets, partitions data for IID/non-IID settings, and runs the centralized and federated training workflows.

# %%
import os
import sys
sys.path.append(os.path.abspath('..'))
from src.utils.experiment import ExperimentRunner

runner = ExperimentRunner(results_root='../results')
print('Experiment runner loaded successfully')

# %%
# To execute the full experiment pipeline, uncomment the line below.
# summary = runner.run_all()
# summary.head()
